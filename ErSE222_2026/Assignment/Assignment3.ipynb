# %% [markdown]
# # Using the normalized dataset *SeismicEventsDetectionPicking_Normalized**, develop neural network models for **sample-based seismic event detection and P-wave picking**.
#
# ## Q1) Neural Network Architecture
# Experiment with different neural network architectures to achieve the best performance. You may modify:
# - Number of layers and neurons
# - Activation functions
#
# Compare performance using appropriate metrics.
#
# ---
#
# ## Q2) Input Data Transformation
# Investigate whether applying additional transformations to the input data improves performance. Examples include:
# - Fourier Transform (FFT)
# - Spectrogram
# - Short-Time Fourier Transform (STFT)
# - Wavelet Transform
#
# Compare results before and after transformation.
#
# ---
#
# ## Q3) Training Data Size Analysis
# Reduce the size of the training dataset (e.g., 75%, 50%, 25%, 10%) and evaluate the model performance.
#
# Report and compare the test results for each case and discuss the impact of training data size.
