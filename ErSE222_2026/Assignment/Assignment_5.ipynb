# %% [markdown]
# ## Q1) Using the clean Marmousi2 dataset named "Marmousi2_5hz_Data," with the aim of denoising through Deep Image Prior (DIP) in an unsupervised approach, proceed with the following tasks:

# %% [markdown]
# 1. Determine the most suitable initialization for the noise.
#
# 2. Identify the optimal hyperparameters for the network.
#
# 3. Establish the best early stopping criteria for the designed network.
#
# 4. Evaluate and compare the Signal-to-Noise Ratio (SNR) before and after the denoising process.

# %% [markdown]
# ## Q2) Modify the hyperparameters of PatchUNET to obtain the best possible results, and then compare these results with those from Q1.
#
# # Additionally, consider replacing the fully connected layers with CNN layers within PatchUNET and observe the effects of this modification.
