# %% [markdown]
# ## Using the dataset "data/WellLog/well4tutorial2.xlsx" with the objective of well-log missing prediction through a deep learning network in a supervised manner, complete the following tasks:

# %% [markdown]
# 1. Determine the optimal hyperparameters for the networks; RNN, GRU, and LSTM.
#
# 2. Evaluate the test results using RMSE and R2 Score.
#
# 3. Substitute all layers with BiDirectional and re-evaluate the performance.
#
# 4. Compare the results from all models and determine the best-performing model, providing rationale for the selection.
# 5. Change the sequence length to 16 and re-evaluate the models' performance.
