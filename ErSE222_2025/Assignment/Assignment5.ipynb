# %% [markdown]
# ## Q1) Using the dataset in the "Salt folder" with the objective of segmenting salt bodies through a deep learning network in a supervised manner, complete the following tasks:

# %% [markdown]
# 1. Replace the U-Net architecture with a different architecture, such as ResNet.
#
# 2. Determine the optimal hyperparameters for the network.
#
# 3. Evaluate the test results using accuracy and Intersection over Union (IoU).
#
# 4. Substitute all layers with Bayesian layers and estimate the uncertainty of the predicted output.
